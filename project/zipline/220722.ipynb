# %%
import zipline
# Out:
# -------------------------------------------------------------------
# ModuleNotFoundError               Traceback (most recent call last)
# <ipython-input-1-ab8bff6e5ffb> in <module>
# ----> 1 import zipline
#
# ModuleNotFoundError: No module named 'zipline'

# %%
# !pip install zipline
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\NOTEBOOK\.conda\envs\py36\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\NOTEBOOK\\AppData\\Local\\Temp\\pip-install-5tldl0ko\\zipline\\setup.py'"'"'; __file__='"'"'C:\\Users\\NOTEBOOK\\AppData\\Local\\Temp\\pip-install-5tldl0ko\\zipline\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\NOTEBOOK\AppData\Local\Temp\pip-wheel-p8pnl8yi'
#        cwd: C:\Users\NOTEBOOK\AppData\Local\Temp\pip-install-5tldl0ko\zipline\
#   Complete output (291 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\zipline
#   copying zipline\algorithm.py -> build\lib.win-amd64-3.6\zipline
# ...

# %%
import pandas

# %%
import zipline
# Out:
# -------------------------------------------------------------------
# ModuleNotFoundError               Traceback (most recent call last)
# <ipython-input-6-ab8bff6e5ffb> in <module>
# ----> 1 import zipline
#
# ModuleNotFoundError: No module named 'zipline'
